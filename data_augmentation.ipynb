# %%
from tensorflow.keras.utils import img_to_array, load_img

# %%
img = load_img('img.jpg')

# %%
img.show()

# %%
X = img_to_array(img)

# %%
X
# Out:
# array([[[100.,  63.,  45.],
#         [100.,  63.,  45.],
#         [100.,  63.,  45.],
#         ...,
#         [184., 118.,  92.],
#         [184., 118.,  92.],
#         [184., 118.,  92.]],
#
#        [[100.,  63.,  45.],
#         [100.,  63.,  45.],
#         [100.,  63.,  45.],
#         ...,
#         [184., 118.,  92.],
#         [184., 118.,  92.],
#         [184., 118.,  92.]],
#
#        [[100.,  63.,  45.],
#         [100.,  63.,  45.],
#         [ 99.,  62.,  44.],
#         ...,
#         [185., 119.,  93.],
#         [184., 118.,  92.],
#         [184., 118.,  92.]],
#
#        ...,
#
#        [[ 48.,  30.,  16.],
#         [ 33.,  15.,   1.],
#         [ 34.,  16.,   2.],
#         ...,
#         [120.,  87.,  78.],
#         [128.,  95.,  86.],
#         [128.,  95.,  86.]],
#
#        [[ 75.,  57.,  43.],
#         [ 46.,  28.,  14.],
#         [ 38.,  20.,   6.],
#         ...,
#         [129.,  96.,  89.],
#         [134., 101.,  94.],
#         [134., 101.,  94.]],
#
#        [[ 83.,  65.,  51.],
#         [ 45.,  27.,  13.],
#         [ 37.,  19.,   7.],
#         ...,
#         [131.,  98.,  91.],
#         [138., 105.,  98.],
#         [139., 106.,  99.]]], dtype=float32)

# %%
X.shape
# Out:
# (329, 474, 3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import numpy as np

X = np.expand_dims(X, axis=0)   # Now shape becomes (1, 329, 474, 3)

X.shape
# Out:
# (1, 1, 329, 474, 3)

# %%
datagen = ImageDataGenerator(
        rotation_range = 40,
        width_shift_range = 0.2,
        height_shift_range = 0.2,
        rescale = 1./255,
        shear_range = 0.2,
        zoom_range = 0.2,
        horizontal_flip = True,)

# %%
i=0
for batch in datagen.flow(X, batch_size=1, save_to_dir = 'augmented_images', save_prefix = 'elephant', save_format = 'jpeg'):
    i += 1
    if i>10:
        break
