# %%
from tensorflow.keras.utils import img_to_array, load_img

# %%
img = load_img('img.jpg')

# %%
img.show()

# %%
X = img_to_array(img)

# %%
X
# Out:
# array([[[100.,  63.,  45.],
#         [100.,  63.,  45.],
#         [100.,  63.,  45.],
#         ...,
#         [184., 118.,  92.],
#         [184., 118.,  92.],
#         [184., 118.,  92.]],
#
#        [[100.,  63.,  45.],
#         [100.,  63.,  45.],
#         [100.,  63.,  45.],
#         ...,
#         [184., 118.,  92.],
#         [184., 118.,  92.],
#         [184., 118.,  92.]],
#
#        [[100.,  63.,  45.],
#         [100.,  63.,  45.],
#         [ 99.,  62.,  44.],
#         ...,
#         [185., 119.,  93.],
#         [184., 118.,  92.],
#         [184., 118.,  92.]],
#
#        ...,
#
#        [[ 48.,  30.,  16.],
#         [ 33.,  15.,   1.],
#         [ 34.,  16.,   2.],
#         ...,
#         [120.,  87.,  78.],
#         [128.,  95.,  86.],
#         [128.,  95.,  86.]],
#
#        [[ 75.,  57.,  43.],
#         [ 46.,  28.,  14.],
#         [ 38.,  20.,   6.],
#         ...,
#         [129.,  96.,  89.],
#         [134., 101.,  94.],
# ...

# %%
X.shape
# Out:
# (329, 474, 3)
